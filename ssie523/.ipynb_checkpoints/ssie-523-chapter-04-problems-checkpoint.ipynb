# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def modela(init, itr, scale):
    '''
    Uniform timesteps
    '''
    hist_val = [init]
    for each in range(0, itr):
        hist_val.append(hist_val[each]*scale)
    return np.array(hist_val)

# %%
run1 = modela(init=1, itr=30, scale=1.1)

# %%
plt.plot(run1)
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 1')
plt.show()

# %%
a = 1.1
def initialize():
    global x, result, t, timesteps
    x=1
    result = [x]
    t=0
    timesteps = [t]
    
def observe():
    global x, result, t, timesteps
    result.append(x)
    timesteps.append(t)

def update():
    global x, result, t, timesteps
    x = a * x
    t += 0.1
    
initialize()
while t < 3.:
    update()
    observe()
plt.plot(timesteps, result)
plt.show()

# %%
hist_time = [0]
hist_val = [1]
time_init = 0
scale = 1.1
while time_init < 3:
    hist_val.append(scale * hist_val[-1])
    hist_time.append(time_init + 0.1)
    time_init += 0.1

# %%
def modelb(val_init, time_init, scale, nrange, step):
    hist_val = [val_init]
    hist_time = [time_init]
    
    while time_init < nrange:
        hist_val.append(scale * hist_val[-1])
        hist_time.append(time_init + 0.1)
        time_init += step
    return_dict = {}
    return_dict['time'] = hist_time 
    return_dict['values'] = hist_val
    return return_dict

# %%
run2 = modelb(val_init=1, time_init=0, scale=1.1, nrange=3, step=0.1)

# %%
plt.plot(run2['time'], run2['values'])
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 2')
plt.show()

# %%
def modelc(init, itr, scale, constant):
    hist_val = [init]
    for each in range(0, itr):
        hist_val.append(hist_val[each]*scale + constant)
    return np.array(hist_val)

# %%
run3 = modelc(init=1, itr=30, scale=1.1, constant=1)
plt.plot(run3)
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 3')
plt.show()

# %%
def modeld(xinit, yinit, itr, ycoef, xcoef):
    xresult = [xinit]
    yresult = [yinit]
    
    for _ in range(0, itr):
        xi = xcoef * xresult[-1] + yresult[-1] 
        yi = ycoef * xresult[-1] + yresult[-1]
        
        xresult.append(xi)
        yresult.append(yi)
        
    result = {}
    result['xresult'] = xresult
    result['yresult'] = yresult
    
    return result

# %%
run4 = modeld(xinit=1, yinit=1, itr=30, ycoef=-0.5, xcoef=0.5)

# %%
plt.plot(run4['xresult'], label='xresult')
plt.plot(run4['yresult'], 'g--', label='yresult')
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 4')
plt.legend()
plt.show()

# %%
plt.plot(run4['xresult'], run4['yresult'])
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 4')
plt.show()

# %%
run5 = modeld(xinit=1, yinit=1, itr=30, ycoef=-0.05, xcoef=0.75)
plt.plot(run5['xresult'], run5['yresult'])
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 5')
plt.show()

# %%
plt.plot(run5['xresult'], label='xresult')
plt.plot(run5['yresult'], 'g--', label='yresult')
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 5')
plt.legend()
plt.show()

# %%
def modele(xinit, yinit, itr):
    xresult = [xinit]
    yresult = [yinit]
    
    for _ in range(0, itr):
        xi = xresult[-1] + yresult[-1] 
        yi = xresult[-1]
        
        xresult.append(xi)
        yresult.append(yi)
        
    result = {}
    result['xresult'] = xresult
    result['yresult'] = yresult
    
    return result

# %%
run6 = modele(xinit=1, yinit=1, itr=30)

# %%
plt.plot(run6['xresult'], label='xresult')
plt.plot(run6['yresult'], 'g--', label='yresult')
plt.xlabel('Time \n (seconds)')
plt.ylabel('Model Output \n (arb units)')
plt.title('Run 6')
plt.legend()
plt.show()

# %%
def modelf(xinit, alpha, kconstant, itr):
    '''
    Range of `xinit`: 0 < xinit < kconstant
    '''
    xresults = [xinit]
    
    for _ in range(0, itr):
        coef = (alpha - 1) / kconstant
        xi = ((-coef * xresults[-1]) + alpha) * xresults[-1]
        xresults.append(xi)
        
    results = {}
    results['xresult'] = xresults
    
    return results

# %%
#Exercise 4.9
results = {}

for each in list(np.linspace(0.1, 2, num=7)):
    x = modelf(xinit=4, alpha=each, kconstant=10, itr=30)
    results['alpha: ' + str(each)] = x

plt.figure(figsize=(15, 5))
for each in list(results.keys()):
    plt.plot(results[each]['xresult'], label=str(each))
    plt.legend()
    plt.xlabel('Time \n (seconds)', fontsize=14)
    plt.ylabel('Model Output \n (arb units)', fontsize=14)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title('Exercise 4.9: Alpha Variation', fontsize=14)
plt.show()

# %%
#Exercise 4.9
results = {}

for each in list(np.linspace(0.1, 5, num=5)):
    each_x = modelf(xinit=each, alpha=1.05, kconstant=10, itr=30)
    results['alpha: ' + str(each)] = each_x

plt.figure(figsize=(20, 5))
for each in list(results.keys()):
    plt.plot(results[each]['xresult'], label=str(each))
    plt.legend()
    plt.xlabel('Time \n (seconds)', fontsize=14)
    plt.ylabel('Model Output \n (arb units)', fontsize=14)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title('Exercise 4.9', fontsize=14)
plt.show()

# %%
from itertools import product
lista = list(np.linspace(0.01, 5, num=7))
listb = list(np.linspace(0.01, 2, num=8))
param_space = [(a, b) for a, b in product(lista, listb)]
results = {}
for each in param_space:
    each_x = modelf(xinit=float(each[0]), alpha=float(each[1]), kconstant=10, itr=30)
    results['param: ' + str(each)] = each_x

# %%
plt.figure(figsize=(20, 20))
for each in list(results.keys()):
    plt.plot(results[each]['xresult'], label=str(each))
    plt.legend()
    plt.xlabel('Time \n (seconds)', fontsize=14)
    plt.ylabel('Model Output \n (arb units)', fontsize=14)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title('Exercise 4.9, Grid Search', fontsize=14)
plt.show()

# %%
def modelg(r_param, k_constant, xinit, itr):
    xresults = [xinit]
    
    for each in range(0, itr):
        coef = xresults[-1] / k_constant
        xi = xresults[-1] + (r_param * xresults[-1] * (1 - coef))
        
        xresults.append(xi)
        
    results = {}
    results['xresults'] = xresults
        
    return results

# %%
run9 = modelg(r_param=0.1, k_constant=9, xinit=1, itr=300)
plt.plot(run9['xresults'])
plt.show()

# %%
listr = list(np.linspace(0.001, 2, num=15))

# %%
#Exercise 4.9
results = {}

for each in listr:
    x = modelg(r_param=each, k_constant=100, xinit=1, itr=30)
    results['r_param: ' + str(each)] = x

plt.figure(figsize=(15, 5))
for each in list(results.keys()):
    plt.plot(results[each]['xresults'], label=str(each))
    plt.legend()
    plt.xlabel('Time \n (seconds)', fontsize=14)
    plt.ylabel('Model Output \n (arb units)', fontsize=14)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title('Exercise 4.9: Alpha Variation', fontsize=14)
plt.show()

# %%
from itertools import product
lista = list(np.linspace(0.001, 2, num=15))
listb = list(np.linspace(1, 5, num=8))
param_space = [(a, b) for a, b in product(lista, listb)]

results = {}
for each in param_space:
    each_x = modelg(r_param = float(each[0]), k_constant = float(each[1]), xinit = 1, itr = 30)
    results['param: ' + str(each)] = each_x

plt.figure(figsize=(20, 20))
for each in list(results.keys()):
    plt.plot(results[each]['xresults'], label=str(each))
    plt.legend()
    plt.xlabel('Time \n (seconds)', fontsize=14)
    plt.ylabel('Model Output \n (arb units)', fontsize=14)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.title('Exercise 4.9, Grid Search', fontsize=14)
plt.show()

# %%
def modelh(itr, alpha, xinit):
    xresults = [xinit]
    
    for each in range(0, itr):
        xi = ((xresults[-1]*xresults[-1]) + alpha) * xresults[-1]
        xresults.append(xi)
    
    results = {}
    results['xresults'] = xresults
    return results

# %%
run10 = modelh(itr=100, alpha=1, xinit=1.0)
plt.plot(run10['xresults'])
plt.show()

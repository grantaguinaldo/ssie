# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#model knowledge development about SSIE 523 Materials

# %%
n = 30
def initialize():
    global x, a, s, resultx, resulta, results
    x = 0.05 #Residual knowledge before starting class
    a = 1 #attention.
    s = 0.05
    resultx = [x]
    resulta = [a]
    results = [s]
    
def observe():
    global x, a, s, resultx, resulta, results
    resultx.append(x)
    resulta.append(a)
    results.append(s)
    
def update():
    global x, a, s, resultx, resulta, results

    # x: knowledge
    # a: attention 
    # s: stress
    nx = x + a * (1/n) * (1-s)
    na = a - x * a + 0.1 * s #
    # Reset stress levels.
    #if s > 1:
    #    ns = 0.05
    #else:
    ns = s + 0.1 * s
    x, a, s = nx, na, ns
    
# Updates: Limit the amount of stress

# %%
initialize()
for i in range(0, n):
    update()
    observe()
plt.plot(resultx, label = 'knowledge')
plt.plot(resulta, label='attention')
plt.plot(results, label='stress')
plt.legend()
plt.show()

# %%
def model(resid, attn, stress, sparam, itr, lnoise, unoise):
    result_resid = [resid]
    result_attn = [attn]
    result_stress = [stress]
    
    noise = np.random.uniform(lnoise, unoise)
    
    for _ in range(0, itr):
        nx = result_resid[-1] + result_attn[-1] * (1/itr) * (1-result_stress[-1]) * noise
        na = result_attn[-1] - result_resid[-1] * result_attn[-1] + sparam * result_stress[-1]
        ns = result_stress[-1] + sparam * result_stress[-1]
        
        result_resid.append(nx)
        result_attn.append(na)
        result_stress.append(ns)
        
    result = {}
    
    result['learning'] = result_resid
    result['attention'] = result_attn
    result['stress'] = result_stress
    
    return result

# %%
run = model(resid=0.05, attn=1, stress=0.05, sparam=0.1, itr=30, lnoise=0.05, unoise=1.95)
plt.plot(run['learning'], label = 'knowledge')
plt.plot(run['attention'], label='attention')
plt.plot(run['stress'], label='stress')
plt.legend()
plt.show()

# %%
n = 30
def initialize():
    global x, a, s, resultx, resulta, results
    x = 0.05 #Residual knowledge before starting class
    a = 1 #attention.
    s = 0.05
    resultx = [x]
    resulta = [a]
    results = [s]
    
def observe():
    global x, a, s, resultx, resulta, results
    resultx.append(x)
    resulta.append(a)
    results.append(s)
    
def update():
    global x, a, s, resultx, resulta, results

    # x: knowledge
    # a: attention 
    # s: stress
    nx = x + a * (1/n) * (1-s)
    na = a - x * a + 0.1 * s #
    # Reset stress levels.
    #if s > 1:
    #    ns = 0.05
    #else:
    #    ns = s + 0.1 * s
    ns = s + 0.1 * s * (1-s) 
    x, a, s = nx, na, ns
    
# Updates: Limit the amount of stress

# %%
initialize()
for i in range(0, n):
    update()
    observe()
plt.plot(resultx, label = 'knowledge')
plt.plot(resulta, label='attention')
plt.plot(results, label='stress')
plt.legend()
plt.show()

# %%
# ID which quantity I want to modify.
# What type of function is needed to acheive what you're looking for.
# (1-s)

# %%
n = 30
def initialize():
    global x, a, s, resultx, resulta, results
    x = 0.05 #Residual knowledge before starting class
    a = 1 #attention.
    s = 0.05
    resultx = [x]
    resulta = [a]
    results = [s]
    
def observe():
    global x, a, s, resultx, resulta, results
    resultx.append(x)
    resulta.append(a)
    results.append(s)

r_a = 0.1 # Rate of attention increase.
r_s = 0.3 # Rate of stress increase.

def update():
    global x, a, s, resultx, resulta, results

    nx = x + a * (1/n) * (1-s)
    na = a - x * a + r_a * s 
    ns = s + r_s * s * (1-s) 
    x, a, s = nx, na, ns

# %%
initialize()
for i in range(0, n):
    update()
    observe()
plt.plot(resultx, label = 'knowledge')
plt.plot(resulta, label='attention')
plt.plot(results, label='stress')
plt.legend()
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib auto
ax = plt.gca(projection='3d')
ax.plot(resultx, resulta, results)
plt.show()
# Out:
# Using matplotlib backend: MacOSX

# %%
#Find point where all three are equal to zero
x = x + a * (1/n) * (1-s)
a = a - x * a + r_a * s 
s = s + r_s * s * (1-s)

# %%
from sympy import *
x, a, s, n, r_a, r_s = symbols(' x a s n r_a r_s')

# %%
eqn_list = [
    x + a * (1/n) * (1-s) - x,
    a - x * a + r_a * s - a,
    s + r_s * s * (1-s) - s 
]

# %%
#Analytical Solution
#First solution means that with 
#any starting knowledge, nothing 
#is learned if attention and stress are zero.

# Second solution means that with any starting 
# knowledge, nothing is learned if stress is maxed out
# and attention converges to a certain value.

# Equilibrium Point. Point at which all of the values are the same, or 
# point at which the system exhibits no changes.

# set next value to previous value and get eq. points.

solve(eqn_list, [x, a, s])
# Out:
# [(x, 0, 0), (x, r_a/x, 1)]

# %%
nx = x + a * (1/n)
na = a + r_a * s
ns = s + 0.1 * s

#Linear system an be written as a matrix.

A = np.array([[1, 0.5, 0], 
              [0, 1, 0.5], 
              [0, 0, 1.1]])

# %%
B = np.array([0.1, 0.25, 0.0025])
B_prime = B.reshape(3, 1)

# %%
A.dot(B_prime)
# Out:
# array([[0.225  ],
#        [0.25125],
#        [0.00275]])

# %%
C = np.array([[1, 1/30, 0], 
              [0, 1, 0.1], 
              [0, 0, 1.1]])

# %%
np.linalg.eig(C)[0]
# Out:
# array([1. , 1. , 1.1])

# %%
np.linalg.eig(C)[1]
# Out:
# array([[ 1.00000000e+00, -1.00000000e+00,  2.29415734e-01],
#        [ 0.00000000e+00,  6.66133815e-15,  6.88247202e-01],
#        [ 0.00000000e+00,  0.00000000e+00,  6.88247202e-01]])

# %%
A.dot(np.linalg.eig(C)[1][:,1].reshape(3, 1))
# Out:
# array([[-1.00000000e+00],
#        [ 6.66133815e-15],
#        [ 0.00000000e+00]])

# %%
D = np.array([0, 1, -1]).reshape(3, 1)
D
# Out:
# array([[ 0],
#        [ 1],
#        [-1]])

# %%
[[0], [1], [-1]]
# Out:
# [[0], [1], [-1]]

# %%
np.linalg.matrix_power(A, 9) @ [[1], [1], [1]]
# Out:
# array([[16.94869228],
#        [ 7.78973846],
#        [ 2.35794769]])

# %%
np.linalg.matrix_power(A, 1000) @[[0], [1], [-1]]
# Out:
# array([[-6.17483230e+42],
#        [-1.23496646e+42],
#        [-2.46993292e+41]])

# %% [markdown]
# ### Lecture notes from March 11, 2021

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def model(a, x):
    return x+a*x*(1-x)*(x-(1-x))

# %%
domain = np.linspace(0, 1)
plt.plot(domain, domain)
plt.plot(domain, model(a=10, x=domain))
plt.axis('image')
plt.show()

# %%
def model2(aconst, xinit, itr):
    xresults = [xinit]
    for each in range(itr):
        x_new = model(a=aconst, x=xresults[-1])
        xresults.append(x_new)
        
    results = {}
    results['x'] = xresults
    
    return results

# %%
# Chaos happens when you go through many steps
# of period-doubling bifurcation.
run = model2(aconst=2.91, xinit=0.1, itr=50)
plt.plot(run['x'])
plt.show()

# %%
aresult = []
xresult = []
for a in np.arange(3, 4.0, 0.01):
    x = 0.1
    for t in range(500):
        x = model(a=a, x=x)
    for t in range(500):
        x = model(a=a, x=x)
        aresult.append(a)
        xresult.append(x)
plt.plot(aresult, xresult, 'b.', alpha=0.003)
plt.show()

# %%
np.arange(2, 3, 0.01)[0]
# Out:
# 2.0
